# %%
pip install kivy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 53.0 MB/s eta 0:00:00
# ...

# %%
pip install buildozer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 50.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 25.6 MB/s eta 0:00:00
# ...

# %%
from kivy.app import App
from kivy.uix.button import Button
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput

class CalculatorApp(App):
    def build(self):
        self.result = TextInput(font_size=32, readonly=True, halign='right', multiline=False)

        layout = GridLayout(cols=4)
        layout.add_widget(self.result)

        # Buttons for digits and operations
        buttons = [
            ('7', '8', '9', '/'),
            ('4', '5', '6', '*'),
            ('1', '2', '3', '-'),
            ('C', '0', '=', '+')
        ]

        for row in buttons:
            for button in row:
                layout.add_widget(Button(text=button, pos_hint={'center_x': 0.5, 'center_y': 0.5}, on_press=self.on_button_press))

        return layout

    def on_button_press(self, instance):
        current_text = self.result.text
        button_text = instance.text

        if button_text == 'C':
            self.result.text = ''
        elif button_text == '=':
            try:
                self.result.text = str(eval(current_text))
            except Exception:
                self.result.text = 'Error'
        else:
            self.result.text = current_text + button_text

if __name__ == '__main__':
    CalculatorApp().run()
# Out:
# WARNING:kivy:Config: Older configuration version detected (0 instead of 27)
# [WARNING] [Config      ] Older configuration version detected (0 instead of 27)
# WARNING:kivy:Config: Upgrading configuration in progress.
# [WARNING] [Config      ] Upgrading configuration in progress.
# DEBUG:kivy:Config: Upgrading from 0 to 1
# [DEBUG  ] [Config      ] Upgrading from 0 to 1
# INFO:kivy:Kivy: v2.3.0
# INFO:kivy:Logger: Record log in /root/.kivy/logs/kivy_24-12-13_0.txt
# [INFO   ] [Logger      ] Record log in /root/.kivy/logs/kivy_24-12-13_0.txt
# [INFO   ] [Kivy        ] v2.3.0
# INFO:kivy:Kivy: Installed at "/usr/local/lib/python3.10/dist-packages/kivy/__init__.py"
# [INFO   ] [Kivy        ] Installed at "/usr/local/lib/python3.10/dist-packages/kivy/__init__.py"
# INFO:kivy:Python: v3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# [INFO   ] [Python      ] v3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# INFO:kivy:Python: Interpreter at "/usr/bin/python3"
# ...

# %%
from IPython import get_ipython
from IPython.display import display
# !pip install kivy
# !pip install buildozer

from kivy.app import App
from kivy.uix.button import Button
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.lang import Builder # Import Builder

# Define the Kivy language code as a string
kv_string = """
<CalculatorApp>:
    result: result
    GridLayout:
        cols: 4
        TextInput:
            id: result
            font_size: 32
            readonly: True
            halign: 'right'
            multiline: False
        # Buttons for digits and operations
        Button:
            text: '7'
            on_press: app.on_button_press(self)
        Button:
            text: '8'
            on_press: app.on_button_press(self)
        Button:
            text: '9'
            on_press: app.on_button_press(self)
        Button:
            text: '/'
            on_press: app.on_button_press(self)
        Button:
            text: '4'
            on_press: app.on_button_press(self)
        Button:
            text: '5'
            on_press: app.on_button_press(self)
        Button:
            text: '6'
            on_press: app.on_button_press(self)
        Button:
            text: '*'
            on_press: app.on_button_press(self)
        Button:
            text: '1'
            on_press: app.on_button_press(self)
        Button:
            text: '2'
            on_press: app.on_button_press(self)
        Button:
            text: '3'
            on_press: app.on_button_press(self)
        Button:
            text: '-'
            on_press: app.on_button_press(self)
        Button:
            text: 'C'
            on_press: app.on_button_press(self)
        Button:
            text: '0'
            on_press: app.on_button_press(self)
        Button:
            text: '='
            on_press: app.on_button_press(self)
        Button:
            text: '+'
            on_press: app.on_button_press(self)
"""

# Load the Kivy language code
Builder.load_string(kv_string)

class CalculatorApp(App):
    def build(self):
        # The layout and widgets are now defined in the kv_string
        return

    def on_button_press(self, instance):
        current_text = self.root.ids.result.text # Access result using root.ids
        button_text = instance.text

        if button_text == 'C':
            self.root.ids.result.text = '' # Access result using root.ids
        elif button_text == '=':
            try:
                self.root.ids.result.text = str(eval(current_text)) # Access result using root.ids
            except Exception:
                self.root.ids.result.text = 'Error' # Access result using root.ids
        else:
          self.result.text = current_text + button_text

if __name__ == '__main__':
    CalculatorApp().run()
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-bda10d44b1d8> in <cell line: 97>()
#      96
#      97 if __name__ == '__main__':
# ---> 98     CalculatorApp().run()
#
# /usr/local/lib/python3.10/dist-packages/kivy/app.py in run(self)
#     953         '''Launches the app in standalone mode.
#     954         '''
# --> 955         self._run_prepare()
#     956         runTouchApp()
#     957         self._stop()
#
# /usr/local/lib/python3.10/dist-packages/kivy/app.py in _run_prepare(self)
#     922         if not self.built:
#     923             self.load_config()
# --> 924             self.load_kv(filename=self.kv_file)
#     925             root = self.build()
#     926             if root:
#
# /usr/local/lib/python3.10/dist-packages/kivy/app.py in load_kv(self, filename)
#     675         else:
#     676             try:
# ...

# %%
from kivy.app import App
from kivy.uix.button import Button
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.lang import Builder

# Kivy Language code for the app layout
kv_string = """
<CalculatorApp>:
    result: result
    GridLayout:
        cols: 4
        TextInput:
            id: result
            font_size: 32
            readonly: True
            halign: 'right'
            multiline: False
        # Buttons for digits and operations
        Button:
            text: '7'
            on_press: app.on_button_press(self)
        Button:
            text: '8'
            on_press: app.on_button_press(self)
        Button:
            text: '9'
            on_press: app.on_button_press(self)
        Button:
            text: '/'
            on_press: app.on_button_press(self)
        Button:
            text: '4'
            on_press: app.on_button_press(self)
        Button:
            text: '5'
            on_press: app.on_button_press(self)
        Button:
            text: '6'
            on_press: app.on_button_press(self)
        Button:
            text: '*'
            on_press: app.on_button_press(self)
        Button:
            text: '1'
            on_press: app.on_button_press(self)
        Button:
            text: '2'
            on_press: app.on_button_press(self)
        Button:
            text: '3'
            on_press: app.on_button_press(self)
        Button:
            text: '-'
            on_press: app.on_button_press(self)
        Button:
            text: 'C'
            on_press: app.on_button_press(self)
        Button:
            text: '0'
            on_press: app.on_button_press(self)
        Button:
            text: '='
            on_press: app.on_button_press(self)
        Button:
            text: '+'
            on_press: app.on_button_press(self)
"""

Builder.load_string(kv_string)

class CalculatorApp(App):
    def build(self):
        return  # Layout is defined in kv_string

    def on_button_press(self, instance):
        current_text = self.root.ids.result.text
        button_text = instance.text

        if button_text == 'C':
            self.root.ids.result.text = ''
        elif button_text == '=':
            try:
                self.root.ids.result.text = str(eval(current_text))
            except Exception:
                self.root.ids.result.text = 'Error'
        else:
            self.root.ids.result.text = current_text + button_text

if __name__ == '__main__':
    CalculatorApp().run()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-01d2508aac4d> in <cell line: 90>()
#      89
#      90 if __name__ == '__main__':
# ---> 91     CalculatorApp().run()
#
# /usr/local/lib/python3.10/dist-packages/kivy/app.py in run(self)
#     953         '''Launches the app in standalone mode.
#     954         '''
# --> 955         self._run_prepare()
#     956         runTouchApp()
#     957         self._stop()
#
# /usr/local/lib/python3.10/dist-packages/kivy/app.py in _run_prepare(self)
#     922         if not self.built:
#     923             self.load_config()
# --> 924             self.load_kv(filename=self.kv_file)
#     925             root = self.build()
#     926             if root:
#
# /usr/local/lib/python3.10/dist-packages/kivy/app.py in load_kv(self, filename)
#     675         else:
#     676             try:
# ...
